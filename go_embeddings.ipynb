# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('/mnt/d/ML/Kaggle/CAFA6-new/go_embeddings.pkl', 'rb') as f:
    data = pickle.load(f)
    embeddings_dict = data['embeddings']
    go_ids = data['go_ids']

# %%
len(go_ids), len(embeddings_dict)
# Out:
# (40122, 40122)

# %%
len(embeddings_dict['GO:0000001'] ) # Example GO term embedding
# Out:
# 512

# %%
import sys
def print_size(data):
    print(f'{sys.getsizeof(data) / (1024 * 1024):.2f} MB')

# %%
print_size(embeddings_dict)
# Out:
# 0.92 MB
